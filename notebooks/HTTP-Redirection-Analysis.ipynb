# %% [markdown]
# # HTTP Redirection Analysis
# - This notebook demonstrates the basic use of `http_redirections` table by finding the most commonly occuring redirections.
# - Partly based on https://github.com/mozilla/openwpm-crawler/blob/master/analysis/Sample%20Analysis.ipynb

# %%
import re
import json
import sqlite3
import pandas as pd
from collections import defaultdict

# %%
import networkx as nx
import visJS2jupyter.visJS_module

# %%
# import some analysis utilities from https://github.com/englehardt/crawl_utils
import sys
sys.path.append('./crawl_utils/')
import domain_utils as du

# %%
# use the sample sqlite for the 2018-06 stateless crawl
DB = 'sample_2018-06_1m_stateless_census_crawl.sqlite'

# %% [markdown]
# ### Load the redirects and requests

# %%
# Load the data
con = sqlite3.connect(DB)
con.row_factory = sqlite3.Row
cur = con.cursor()
redirects = pd.read_sql_query("SELECT old_channel_id, new_channel_id, visit_id FROM http_redirects"
                              " WHERE old_channel_id IS NOT NULL AND is_sts_upgrade=0;", con)
requests = pd.read_sql_query("SELECT url, channel_id FROM http_requests;", con)

# %%
# build a map of channel_id to request url
channel_id_to_url_map = dict(zip(requests.channel_id, requests.url))

# %%
redirects["old_url"] = redirects["old_channel_id"].map(lambda x: channel_id_to_url_map.get(x, None))
redirects["new_url"] = redirects["new_channel_id"].map(lambda x: channel_id_to_url_map.get(x, None))

# %%
# Eliminate redirections that don't have a corresponding request in the http_requests table
redirects = redirects[~redirects.new_url.isnull()]

# %%
redirects['old_ps1'] = redirects['old_url'].apply(du.get_ps_plus_1)
redirects['new_ps1'] = redirects['new_url'].apply(du.get_ps_plus_1)

# %%
# only count redirections between different PS+1's
redirects = redirects[redirects.old_ps1!=redirects.new_ps1]

# %%
# only count a (src-dst) pair once on a website
redirects.drop_duplicates(subset=["visit_id", "old_ps1", "new_ps1"], inplace=True)

# %%
redirects.head()
# Out:
#                             old_channel_id  \
# 29  {bf5b720e-3b7d-4c24-850d-f9ca2e32771f}
# 38  {023b1347-20c6-4491-bdac-ff132a905586}
# 41  {651404cf-6f90-4b2e-8d20-f25ee94e5fca}
# 44  {80fd6229-1375-47b3-affd-56e2463e0fee}
# 57  {6b874783-5896-49c0-bb8a-f4d95167884d}
#
#                             new_channel_id  visit_id  \
# 29  {651404cf-6f90-4b2e-8d20-f25ee94e5fca}         3
# 38  {edd381eb-b452-4540-b000-174e2b4974b8}         8
# 41  {6ba116ef-16f5-4c16-8bd1-4a1d962faf5b}         3
# 44  {9c920524-7670-4a81-805f-4a54e2dba5f5}        10
# 57  {d55bedf4-3440-4019-82d4-d045f0726101}         9
#
#                                               old_url  \
# 29  https://facebook.com/security/hsts-pixel.gif?c...
# 38  https://cm.g.doubleclick.net/pixel?google_nid=...
# 41    https://fbcdn.net/security/hsts-pixel.gif?c=2.5
# 44            http://mat1.qq.com/www/images/ind36.gif
# 57  https://bh.contextweb.com/bh/rtset?pid=557477&...
#
#                                               new_url          old_ps1  \
# 29    https://fbcdn.net/security/hsts-pixel.gif?c=2.5     facebook.com
# 38  https://analytics.twitter.com/tpm?pid=969&puid...  doubleclick.net
# 41      https://fbsbx.com/security/hsts-pixel.gif?c=5        fbcdn.net
# 44         http://mat1.gtimg.com/www/images/ind36.gif           qq.com
# 57  https://s.amazon-adsystem.com/ecm3?id=Q1Bt741B...   contextweb.com
#
#                 new_ps1
# 29            fbcdn.net
# 38          twitter.com
# 41            fbsbx.com
# 44            gtimg.com
# 57  amazon-adsystem.com

# %% [markdown]
# ### Most frequent redirection domain pairs

# %%
redirects.groupby(['old_ps1', 'new_ps1']).size().reset_index(name='# sites').\
    sort_values(by=['# sites'], ascending=False).head(10)
# Out:
#                    old_ps1             new_ps1  # sites
# 879        doubleclick.net          google.com      295
# 1097  google-analytics.com     doubleclick.net      246
# 1018       everesttech.net  rubiconproject.com       88
# 930        doubleclick.net  rubiconproject.com       87
# 297             adsrvr.org  rubiconproject.com       78
# 1284           mathtag.com  rubiconproject.com       72
# 1598    rubiconproject.com           yahoo.com       70
# 1961             yahoo.com  rubiconproject.com       68
# 1587    rubiconproject.com     doubleclick.net       68
# 1013       everesttech.net           openx.net       68

# %% [markdown]
# ### Top redirection targets
# - Top 10 domains that redirect to other domains.

# %%
redirects.groupby(['new_ps1']).size().reset_index(name='# sites').\
    sort_values(by=['# sites'], ascending=False).head(10)
# Out:
#                  new_ps1  # sites
# 399         pubmatic.com     1242
# 176      doubleclick.net      765
# 367            openx.net      575
# 159           demdex.net      524
# 424   rubiconproject.com      490
# 108          bluekai.com      382
# 70   amazon-adsystem.com      326
# 235           google.com      309
# 286             krxd.net      272
# 101        bidswitch.net      229

# %% [markdown]
# ### Top redirection sources
# - Top 10 domains that are redirected to from other domains.

# %%
redirects.groupby(['old_ps1']).size().reset_index(name='counts').\
    sort_values(by=['counts'], ascending=False).head(10)
# Out:
#                   old_ps1  counts
# 164       doubleclick.net    1134
# 45             adsrvr.org     608
# 179       everesttech.net     474
# 92          bidswitch.net     401
# 285           mathtag.com     395
# 35              adnxs.com     367
# 213  google-analytics.com     246
# 383    rubiconproject.com     220
# 493             yahoo.com     198
# 379             rlcdn.com     189

# %%
redirection_pair_counts = redirects.groupby(['old_ps1', 'new_ps1']).size().\
    reset_index(name='counts').sort_values(by=['counts'], ascending=False).values.tolist()

# %%
DG = nx.DiGraph()
DG.add_weighted_edges_from(redirection_pair_counts)

# %%
nodes = list(DG.nodes())
edges = list(DG.edges())

# %%
# define the initial positions of the nodes using networkx's spring_layout function, and add to the nodes_dict.
pos = nx.spring_layout(DG)

nodes_dict = [{"id":n,
              "x":pos[n][0]*1000,
              "degree":nx.degree(DG,n),
              "y":pos[n][1]*1000} for n in nodes]

node_map = dict(zip(nodes,range(len(nodes))))  # map to indices for source/target in edges

edges_dict = [{"source":node_map[edges[i][0]],
               "target":node_map[edges[i][1]]}
              for i in range(len(edges))]

visJS2jupyter.visJS_module.visjs_network(nodes_dict, edges_dict,
                                         edge_arrow_to=True,
                                         physics_enabled=True)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file0"];    frame.runVis([{"node_shape": "dot", "degree": 3, "title": "7eer.net", "color": "#8BA8D3", "y": 108.01876336336136, "x": 206.54074847698212, "border_width": 0, "id": "7eer.net"}, {"node_shape": "dot", "degree": 1, "title": "adp.com", "color": "#8BA8D3", "y": 826.6072869300842, "x": 458.1300914287567, "border_width": 0, "id": "adp.com"}, {"node_shape": "dot", "degree": 2, "title": "qtmojo.com", "color": "#8BA8D3", "y": 275.66060423851013, "x": 783.2682728767395, "border_width": 0, "id": "qtmojo.com"}, {"node_shape": "dot", "degree": 1, "title": "atlassian.net", "color": "#8BA8D3", "y": -730.9852838516235, "x": 403.02252769470215, "border_width": 0, "id": "atlassian.net"}, {"node_shape": "dot", "degree": 2, "title": "eyereturn.com", "color": "#8BA8D3", "y": -133.1779509782791, "x": 266.31277799606323, "border_width": 0, "id": "eyereturn.com"}, {"node_shape": "dot", "degree": 54, "title": "3lift.com", "color": "#8BA8D3", "y": -15.166759490966797, "x": 66.73179566860199, "border_width": 0, "id": "3lift.com"}, {"node_shape": "dot", "degree": 5, "title": "atdmt.com", "color": "#8BA8D3", "y": 19.623178988695145, "x": 37.86572441458702, "border_width": 0, "id": "atdmt.com"}, {"node_shape": "dot", "degree": 2, "title": "recreativ.ru", "color": "#8BA8D3", "y": -45.74078321456909, "x": 704.9563527107239, "border_width": 0, "id": "recreativ.ru"}, {"node_shape": "dot", "degree": 6, "title": "reachmax.cn", "color": "#8BA8D3", "y": -29.98899482190609, "x": -118.94796788692474, "border_width": 0, "id": "reachmax.cn"}, {"node_shape": "dot", "degree": 2, "title": "telekom.com", "color": "#8BA8D3", "y": -93.89802813529968, "x": 773.6278176307678, "border_width": 0, "id": "telekom.com"}, {"node_shape": "dot", "degree": 3, "title": "tmall.com", "color": "#8BA8D3", "y": -696.7321634292603, "x": 84.50385183095932, "border_width": 0, "id": "tmall.com"}, {"node_shape": "dot", "degree": 1, "title": "kompasads.com", "color": "#8BA8D3", "y": -704.4028639793396, "x": -147.45236933231354, "border_width": 0, "id": "kompasads.com"}, {"node_shape": "dot", "degree": 3, "title": "erne.co", "color": "#8BA8D3", "y": 77.68327742815018, "x": 128.41735780239105, "border_width": 0, "id": "erne.co"}, {"node_shape": "dot", "degree": 2, "title": "mfadsrvr.com", "color": "#8BA8D3", "y": 652.7528166770935, "x": -473.5749661922455, "border_width": 0, "id": "mfadsrvr.com"}, {"node_shape": "dot", "degree": 1, "title": "citicards.com", "color": "#8BA8D3", "y": 865.7695651054382, "x": -269.6066200733185, "border_width": 0, "id": "citicards.com"}, {"node_shape": "dot", "degree": 5, "title": "exe.bid", "color": "#8BA8D3", "y": -332.6641917228699, "x": 109.66023802757263, "border_width": 0, "id": "exe.bid"}, {"node_shape": "dot", "degree": 9, "title": "crsspxl.com", "color": "#8BA8D3", "y": 511.0780596733093, "x": -128.15116345882416, "border_width": 0, "id": "crsspxl.com"}, {"node_shape": "dot", "degree": 1, "title": "googlesyndication.com", "color": "#8BA8D3", "y": -233.64044725894928, "x": -933.1669211387634, "border_width": 0, "id": "googlesyndication.com"}, {"node_shape": "dot", "degree": 2, "title": "nex8.net", "color": "#8BA8D3", "y": 179.80456352233887, "x": -104.00614142417908, "border_width": 0, "id": "nex8.net"}, {"node_shape": "dot", "degree": 1, "title": "morgdm.ru", "color": "#8BA8D3", "y": -227.67482697963715, "x": 322.8803873062134, "border_width": 0, "id": "morgdm.ru"}, {"node_shape": "dot", "degree": 2, "title": "ruliweb.com", "color": "#8BA8D3", "y": 929.9887418746948, "x": -295.95693945884705, "border_width": 0, "id": "ruliweb.com"}, {"node_shape": "dot", "degree": 2, "title": "ew3.io", "color": "#8BA8D3", "y": 36.000851541757584, "x": 99.47477281093597, "border_width": 0, "id": "ew3.io"}, {"node_shape": "dot", "degree": 19, "title": "exelator.com", "color": "#8BA8D3", "y": -11.3387 ...
