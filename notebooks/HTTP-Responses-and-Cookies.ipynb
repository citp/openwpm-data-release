# %% [markdown]
# # HTTP Response and Redirection Analysis
# - This notebook demonstrates the basic use of `http_responses` table and HTTP `Location` header by finding the most commonly occuring redirections.
# - Partly based on https://github.com/mozilla/openwpm-crawler/blob/master/analysis/Sample%20Analysis.ipynb

# %%
import re
import json
import sqlite3
import pandas as pd
from collections import defaultdict

# %%
# import some analysis utilities from https://github.com/englehardt/crawl_utils
import sys
sys.path.append('./crawl_utils/')
import domain_utils as du
import analysis_utils as au

# %%
# use the sample sqlite for the 2018-06 stateless crawl
DB = 'sample_2018-06_1m_stateless_census_crawl.sqlite'

# %% [markdown]
# ### Load the responses

# %%
# Load the data
con = sqlite3.connect(DB)
con.row_factory = sqlite3.Row
cur = con.cursor()
resps = pd.read_sql_query("SELECT * FROM http_responses", con)

# %%
total_sites = resps['visit_id'].nunique()
print "Database contains %s HTTP responses on %d sites" %(len(resps), total_sites)
# Out:
# Database contains 153693 HTTP responses on 967 sites

# %%
resps.head()
# Out:
#    id  crawl_id  visit_id                   url method referrer  \
# 0   1         9         9    http://amazon.com/    GET
# 1   2         7         7  http://google.co.in/    GET
# 2   3         9         9   https://amazon.com/    GET
# 3   4         1         1    http://google.com/    GET
# 4   5         2         2   http://youtube.com/    GET
#
#    response_status response_status_text  is_cached  \
# 0              301    Moved Permanently          0
# 1              301    Moved Permanently          0
# 2              301    Moved Permanently          0
# 3              301    Moved Permanently          0
# 4              301    Moved Permanently          0
#
#                                              headers  \
# 0  [["Server","Server"],["Date","Wed, 27 Jun 2018...
# 1  [["Location","http://www.google.co.in/"],["Con...
# 2  [["Server","Server"],["Date","Wed, 27 Jun 2018...
# 3  [["Location","http://www.google.com/"],["Conte...
# 4  [["Content-Length","0"],["Location","https://y...
#
#                                channel_id                  location  \
# 0  {7503bbce-c0a7-4cfd-aa9a-6b023c81184d}       https://amazon.com/
# 1  {2e5da2ee-aa63-4295-8b01-bdd1e02282cb}  http://www.google.co.in/
# 2  {825cc55c-1331-4bde-802b-16005b100e56}   https://www.amazon.com/
# 3  {ab3afb0f-9661-423e-8807-430687139415}    http://www.google.com/
# 4  {364f2ffa-936f-458b-a895-530ea15681b7}      https://youtube.com/
#
#                  time_stamp content_hash
# 0  2018-06-27T14:19:39.650Z         None
# 1  2018-06-27T14:19:39.660Z         None
# 2  2018-06-27T14:19:39.676Z         None
# 3  2018-06-27T14:19:39.682Z         None
# 4  2018-06-27T14:19:39.684Z         None

# %% [markdown]
# ### Add additional columns to help with analysis

# %%
# Add the public suffix + 1 of a bunch of the URL columns
resps['url_ps1'] = resps['url'].apply(du.get_ps_plus_1)
resps['location_ps1'] = resps['location'].apply(du.get_ps_plus_1)

# %% [markdown]
# ### Find the domains that redirections between domains

# %%
from tqdm import tqdm

# Join by `site_visits` table to get the site URL.
query = """SELECT sv.site_url, sv.visit_id,
    res.url, res.location
    FROM http_responses as res LEFT JOIN site_visits as sv
    ON sv.visit_id = res.visit_id
    """
redirections = defaultdict(int)  # (source domain, destination domain)=> frequency (num. of distinct sites)
redirections_by_visit_id = defaultdict(set)  # we keep a track of redirections observed on each domain

for row in tqdm(cur.execute(query)):
    # visit_id, script_url, operation, arguments, symbol, value = row[0:6]
    visit_id = row["visit_id"]
    site_url = row["site_url"]
    url = row["url"]
    location = row["location"]
    url_ps1 = du.get_ps_plus_1(url)
    location_ps1 = du.get_ps_plus_1(location)
    # only count redirections between different PS+1's
    if location_ps1 and (location_ps1 != url_ps1):
        # make sure we didn't count this redirection on this site
        if (url_ps1, location_ps1) not in redirections_by_visit_id[visit_id]:
            redirections[(url_ps1, location_ps1)] += 1
            redirections_by_visit_id[visit_id].add((url_ps1, location_ps1))
# Out:
# 153693it [00:06, 22331.00it/s]

# %% [markdown]
# ### Most frequent redirections between domains

# %%
for count, redirection_pair in sorted( ((v,k) for k,v in redirections.iteritems()), reverse=True):
    if count > 10:  # only prints redirections happened on more than 10 sites
        print redirection_pair[0], "=>", redirection_pair[1], count
# Out:
# doubleclick.net => google.com 295
# google-analytics.com => doubleclick.net 248
# everesttech.net => rubiconproject.com 88
# doubleclick.net => rubiconproject.com 87
# adsrvr.org => rubiconproject.com 78
# mathtag.com => rubiconproject.com 73
# rubiconproject.com => yahoo.com 70
# rubiconproject.com => doubleclick.net 69
# yahoo.com => rubiconproject.com 68
# everesttech.net => openx.net 68
# everesttech.net => pubmatic.com 67
# doubleclick.net => pubmatic.com 67
# rlcdn.com => pubmatic.com 64
# rfihub.com => pubmatic.com 64
# adsrvr.org => pubmatic.com 64
# doubleclick.net => openx.net 63
# everesttech.net => demdex.net 60
# adsrvr.org => openx.net 59
# turn.com => openx.net 57
# quantserve.com => pubmatic.com 56
# pubmatic.com => adsymptotic.com 55
# adsymptotic.com => pubmatic.com 55
# adsymptotic.com => adsrvr.org 54
# dotomi.com => pubmatic.com 52
# adsrvr.org => adsymptotic.com 52
# nexac.com => addthis.com 51
# mathtag.com => openx.net 49
# google.com => doubleclick.net 49
# 1rx.io => pubmatic.com 46
# mathtag.com => pubmatic.com 42
# adnxs.com => amazon-adsystem.com 41
# adhigh.net => pubmatic.com 39
# sitescout.com => pubmatic.com 38
# doubleclick.net => bluekai.com 37
# rfihub.com => openx.net 36
# brealtime.com => adnxs.com 36
# tribalfusion.com => pubmatic.com 35
# rubiconproject.com => amazon-adsystem.com 35
# basebanner.com => pubmatic.com 35
# tapad.com => adsrvr.org 34
# gumgum.com => pubmatic.com 34
# advertising.com => pubmatic.com 34
# owneriq.net => pubmatic.com 33
# adsrvr.org => tapad.com 33
# doubleclick.net => demdex.net 32
# bidswitch.net => pubmatic.com 32
# rlcdn.com => krxd.net 31
# ib-ibi.com => mookie1.com 30
# adsymptotic.com => krxd.net 30
# sitescout.com => demdex.net 29
# openx.net => doubleclick.net 29
# everesttech.net => doubleclick.net 29
# doubleclick.net => bidswitch.net 29
# simpli.fi => pubmatic.com 28
# doubleclick.net => adsrvr.org 28
# demdex.net => tapad.com 28
# adsrvr.org => casalemedia.com 28
# adnxs.com => pubmatic.com 28
# pubmatic.com => mxptint.net 27
# mxptint.net => pubmatic.com 27
# taboola.com => basebanner.com 26
# everesttech.net => spotxchange.com 26
# w55c.net => pubmatic.com 25
# tubemogul.com => everesttech.net 25
# media6degrees.com => pubmatic.com 25
# mathtag.com => abmr.net 25
# ipredictive.com => pubmatic.com 25
# bidswitch.net => doubleclick.net 25
# adform.net => pubmatic.com 25
# abmr.net => mathtag.com 25
# rlcdn.com => demdex.net 24
# imrworldwide.com => facebook.com 24
# adsrvr.org => doubleclick.net 24
# facebook.com => atdmt.com 23
# adgrx.com => pubmatic.com 23
# everesttech.net => casalemedia.com 22
# doubleclick.net => eyeota.net 22
# bidr.io => doubleclick.net 22
# adsrvr.org => demdex.net 22
# adnxs.com => bluekai.com 22
# sitescout.com => openx.net 21
# openx.net => yahoo.com 21
# mathtag.com => sonobi.com 21
# mathtag.com => bluekai.com 21
# doubleclick.net => bidr.io 21
# bidswitch.net => company-target.com 21
# bidr.io => contextweb.com 21
# adsrvr.org => sonobi.com 21
# adsrvr.org => bluekai.com 21
# mathtag.com => doubleclick.net 20
# mathtag.com => demdex.net 20
# krxd.net => doubleclick.net 20
# eyereturn.com => pubmatic.com 20
# doubleclick.net => mathtag.com 20
# doubleclick.net => krxd.net 20
# contextweb.com => pubmatic.com 20
# bidr.io => pubmatic.com 20
# advertising.com => openx.net 20
# advertising.com => demdex.net 20
# yahoo.com => bluekai.com 19
# v12group.com => adsymptotic.com 19
# googleadservices.com => doubleclick.net 19
# doubleclick.net => contextweb.com 19
# agkn.com => krxd.net 19
# advertising.com => amazon-adsystem.com 19
# adsymptotic.com => v12group.com 19
# adsafeprotected.com => googletagservices.com 19
# adnxs.com => demdex.net 19
# addthis.com => krxd.net 19
# simpli.fi => bnmla.com 18
# rlcdn.com => ml314.com 18
# openx.net => criteo.com 18
# everesttech.net => bluekai.com 18
# everesttech.net => adnxs.com 18
# doubleclick.net => adnxs.com 18
# bnmla.com => simpli.fi 18
# bluekai.com => doubleclick.net 18
# bidswitch.net => sonobi.com 18
# bidswitch.net => openx.net 18
# w55c.net => bluekai.com 17
# rhythmxchange.com => sonobi.com 17
# everesttech.net => facebook.com 17
# company-target.com => bidswitch.net 17
# advertising.com => bluekai.com 17
# adnxs.com => openx.net 17
# addthis.com => bluekai.com 17
# twitter.com => ads-twitter.com 16
# rubiconproject.com => adsrvr.org 16
# rfihub.com => bluekai.com 16
# pubmatic.com => tapad.com 16
# powerlinks.com => demdex.net 16
# ml314.com => eyeota.net 16
# doubleclick.net => casalemedia.com 16
# contextweb.com => bidr.io 16
# bluekai.com => krxd.net 16
# storygize.net => taboola.com 15
# spotxchange.com => amazon-adsystem.com 15
# rfihub.com => casalemedia.com 15
# gumgum.com => openx.net 15
# exposebox.com => taboola.com 15
# doubleclick.net => taboola.com 15
# doubleclick.net => everesttech.net 15
# doubleclick.net => crwdcntrl.net 15
# doubleclick.net => amazon-adsystem.com 15
# doubleclick.net => adroll.com 15
# creative-serving.com => bidswitch.net 15
# bttrack.com => taboola.com 15
# bnmla.com => pubmatic.com 15
# bidswitch.net => taboola.com 15
# bidswitch.net => creative-serving.com 15
# adsrvr.org => taboola.com 15
# adroll.com => doubleclick.net 15
# adnxs.com => taboola.com 15
# adadvisor.net => agkn.com 15
# zemanta.com => pubmatic.com 14
# zemanta.com => bluekai.com 14
# yahoo.com => pubmatic.com 14
# turn.com => casalemedia.com 14
# simpli.fi => openx.net 14
# rundsp.com => pubmatic.com 14
# openx.net => amazon-adsystem.com 14
# mookie1.com => amazon-adsystem.com 14
# krxd.net => rlcdn.com 14
# gwallet.com => pubmatic.com 14
# eyeota.net => doubleclick.net 14
# eyeota.net => demdex.net 14
# doubleclick.net => spotxchange.com 14
# demdex.net => amazon-adsystem.com 14
# contextweb.com => sonobi.com 14
# casalemedia.com => amazon-adsystem.com 14
# bidswitch.net => amazon-adsystem.com 14
# yahoo.com => amazon-adsystem.com 13
# turn.com => rubiconproject.com 13
# sitescout.com => rubiconproject.com 13
# quantserve.com => openx.net 13
# pubmatic.com => amazon-adsystem.com 13
# mathtag.com => casalemedia.com 13
# impdesk.com => pubmatic.com 13
# emxdgt.com => amazon-adsystem.com 13
# doubleclick.net => tribalfusion.com 13
# dotomi.com => contextweb.com 13
# contextweb.com => amazon-adsystem.com 13
# bluekai.com => zemanta.com 13
# adsrvr.org => krxd.net 13
# adsrvr.org => contextweb.com 13
# adnxs.com => krxd.net 13
# adnxs.com => emxdgt.com 13
# yahoo.com => adsrvr.org 12
# w55c.net => openx.net 12
# tribalfusion.com => rubiconproject.com 12
# tapad.com => myvisualiq.net 12
# stickyadstv.com => tribalfusion.com 12
# spotxchange.com => doubleclick.net 12
# simpli.fi => rubiconproject.com 12
# s3xified.com => pubmatic.com 12
# eyeota.net => ml314.com 12
# dotomi.com => openx.net 12
# bluekai.com => ml314.com 12
# agkn.com => demdex.net 12
# adsrvr.org => advertising.com 12
# adroll.com => yahoo.com 12
# adroll.com => openx.net 12
# adroll.com => casalemedia.com 12
# adroll.com => bidswitch.net 12
# adroll.com => adnxs.com 12
# 1rx.io => amazon-adsystem.com 12
# yahoo.com => demdex.net 11
# tribalfusion.com => krxd.net 11
# tribalfusion.com => advertising.com 11
# tapad.com => contextweb.com 11
# spotxchange.com => adsrvr.org 11
# sharethis.com => crwdcntrl.net 11
# pubmatic.com => tribalfusion.com 11
# ml314.com => demdex.net 11
# doubleclick.net => rfihub.com 11
# bluekai.com => nexac.com 11
# bing.com => demdex.net 11
# avocet.io => cpx.to 11
# agkn.com => tribalfusion.com 11
# afy11.net => sonobi.com 11
# advertising.com => tribalfusion.com 11
# adsrvr.org => spotxchange.com 11
# adroll.com => rlcdn.com 11
# adnxs.com => cpx.to 11
# adform.net => openx.net 11
